# %%
import pandas as pd
import metrics
import chem_utils.mol as mol_utils

# remove rdkit warnings
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
# load df
smiles_col = "Smiles"
generated_smiles_csv_path = "/mnt/ssd2/Chem/photopolymerization_initiator/ML/MolGen/data/results/generated_smiles/20240207132032.csv"
df = pd.read_csv(generated_smiles_csv_path)
df.head()
# Out:
#                                               Smiles
# 0                 CC(=O)O\N=C(\C)c1ccc(Sc2ccccc2)cc1
# 1                  CC(=O)ON=Cc1cc([N+](=O)[O-])ccc1O
# 2  O=Cc1cn(-c2ccccc2)c2ccc(C#Cc3ccc(C=NOC(C)=O)cc...
# 3  c1cc(NC(C(F)(F)C(C(F)(F)F)(F)C(=O)O)(C(F)(F)F)...
# 4     CC(=O)Nc1ccc(C#Cc2cc3c(cc2C=NOC(C)=O)cccc3)cc1

# %%
# remove invalid mols
df = df[df[smiles_col].apply(mol_utils.smiles2mol2smiles) != None]
df = df.dropna()
df.head()
# Out:
#                                               Smiles
# 0                 CC(=O)O\N=C(\C)c1ccc(Sc2ccccc2)cc1
# 1                  CC(=O)ON=Cc1cc([N+](=O)[O-])ccc1O
# 2  O=Cc1cn(-c2ccccc2)c2ccc(C#Cc3ccc(C=NOC(C)=O)cc...
# 3  c1cc(NC(C(F)(F)C(C(F)(F)F)(F)C(=O)O)(C(F)(F)F)...
# 4     CC(=O)Nc1ccc(C#Cc2cc3c(cc2C=NOC(C)=O)cccc3)cc1

# %%
# add symmetry
df['symmetry'] = df[smiles_col].apply(metrics.symmetry)
df.head()
# Out:
#                                               Smiles  symmetry
# 0                 CC(=O)O\N=C(\C)c1ccc(Sc2ccccc2)cc1  0.400000
# 1                  CC(=O)ON=Cc1cc([N+](=O)[O-])ccc1O  0.000000
# 2  O=Cc1cn(-c2ccccc2)c2ccc(C#Cc3ccc(C=NOC(C)=O)cc...  0.266667
# 3  c1cc(NC(C(F)(F)C(C(F)(F)F)(F)C(=O)O)(C(F)(F)F)...  0.384615
# 4     CC(=O)Nc1ccc(C#Cc2cc3c(cc2C=NOC(C)=O)cccc3)cc1  0.142857

# %%
# add oxime_num
df['num_oxime_activation'] = df[smiles_col].apply(metrics.num_oxime_activation)
df.head()
# Out:
#                                               Smiles  symmetry  \
# 0                 CC(=O)O\N=C(\C)c1ccc(Sc2ccccc2)cc1  0.400000
# 1                  CC(=O)ON=Cc1cc([N+](=O)[O-])ccc1O  0.000000
# 2  O=Cc1cn(-c2ccccc2)c2ccc(C#Cc3ccc(C=NOC(C)=O)cc...  0.266667
# 3  c1cc(NC(C(F)(F)C(C(F)(F)F)(F)C(=O)O)(C(F)(F)F)...  0.384615
# 4     CC(=O)Nc1ccc(C#Cc2cc3c(cc2C=NOC(C)=O)cccc3)cc1  0.142857
#
#    num_oxime_activation
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1

# %%
# max fused ring size
df['max_fused_ring_size'] = df[smiles_col].apply(metrics.get_max_fused_ring_size)
df.head()
# Out:
#                                               Smiles  symmetry  \
# 0                 CC(=O)O\N=C(\C)c1ccc(Sc2ccccc2)cc1  0.400000
# 1                  CC(=O)ON=Cc1cc([N+](=O)[O-])ccc1O  0.000000
# 2  O=Cc1cn(-c2ccccc2)c2ccc(C#Cc3ccc(C=NOC(C)=O)cc...  0.266667
# 3  c1cc(NC(C(F)(F)C(C(F)(F)F)(F)C(=O)O)(C(F)(F)F)...  0.384615
# 4     CC(=O)Nc1ccc(C#Cc2cc3c(cc2C=NOC(C)=O)cccc3)cc1  0.142857
#
#    num_oxime_activation  max_fused_ring_size
# 0                     1                    1
# 1                     1                    1
# 2                     1                    2
# 3                     0                    1
# 4                     1                    2

# %%
df.to_csv('oxime_filtered_checkpoint.csv')

# %%
# filter
oxime_num_min = 2
max_fused_ring_size_min = 2
min_symmetry = 0.6

df_filter = df[(df['num_oxime_activation'] >= oxime_num_min) & 
               (df['max_fused_ring_size'] >= max_fused_ring_size_min) &
                (df['symmetry'] >= min_symmetry)
            ]
df_filter
# Out:
#                                                    Smiles  symmetry  \
# 880     CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(...  0.869565
# 961              CC(=O)O\N=C/c1ccc2cc(/C=N\OC(C)=O)ccc2c1  1.000000
# 1315    CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(...  0.869565
# 1546    CCCCCCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c...  0.800000
# 1828    O=C(O/N=C/c1cc2ccccc2cc1/C=N/OC(=O)c1ccccc1)c1...  1.000000
# ...                                                   ...       ...
# 421697          CC(=O)O\N=C1\c2c(cccc2)/C(=N/OC(C)=O)C1=O  0.900000
# 421871  CC(=O)O/N=C\c1ccc2c(c1)Sc1cc(/C=N\OC(C)=O)ccc1N2C  0.923077
# 421942  CCCCCCn1c2ccc(/C(C)=N/OC(C)=O)cc2c2cc(/C(C)=N/...  0.812500
# 422233           CC(=O)O\N=C\c1ccc2ccc(/C=N/OC(C)=O)cc2c1  0.909091
# 422444  CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(...  0.869565
#
#         num_oxime_activation  max_fused_ring_size
# 880                        2                    3
# 961                        2                    2
# 1315                       2                    3
# 1546                       2                    3
# 1828                       2                    2
# ...                      ...                  ...
# 421697                     2                    2
# 421871                     2                    3
# 421942                     2                    3
# 422233                     2                    2
# 422444                     2                    3
#
# [482 rows x 4 columns]

# %%
df_filter.to_csv('oxime_filter.csv')

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from PIL import Image, ImageDraw, ImageFont

# %%
df = pd.read_csv('oxime_pred_vals.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0         592
# 1             1        1190
# 2             2        1725
# 3             3        3407
# 4             4        3686
#
#                                               Smiles  symmetry  \
# 0  CC(=O)O\N=C\c1ccc2c(c1)Sc1cc(/C=N/OC(C)=O)ccc1...  0.666667
# 1  CCC(CCCC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c...  0.833333
# 2  CCCCCCn1c2ccc(/C(C)=N/OC(C)=O)cc2c2cc(/C(C)=N/...  0.812500
# 3  CCCCCCC/C(=N\OC(=O)c1ccccc1)c1ccc2c(c1)Sc1cc(/...  0.928571
# 4  C(CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2c...  0.833333
#
#    num_oxime_activation  max_fused_ring_size  is_able_to_calculate        T1  \
# 0                     2                    3                  True  2.201316
# 1                     2                    3                  True  2.129354
# 2                     2                    3                  True  2.673143
# 3                     2                    3                  True  2.430663
# 4                     2                    3                  True  2.100914
#
#          S1    S1_osc        S2    S2_osc        S3    S3_osc
# 0  3.358353  0.314739  3.799375  0.095388  3.956727  0.446369
# 1  3.494984  2.221143  3.807240  0.860613  3.919722  0.519636
# 2  3.951552  0.043600  4.160967  0.131715  4.536570  0.252301
# 3  3.420066  0.328222  4.021405 -0.020506  4.072446  0.202766
# 4  3.510591  2.140261  3.788762  0.809907  3.919181  0.581851

# %%
smiles = df[df['S1'] > 2.5]['Smiles'].tolist()
print(smiles)
# Out:
# ['CC(=O)O\\N=C\\c1ccc2c(c1)Sc1cc(/C=N/OC(C)=O)ccc1N2c1ccc2c(c1)cccc2', 'CCC(CCCC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(/C(C)=N/OC(C)=O)cc2c2cc(/C(C)=N/OC(C)=O)ccc21', 'CCCCCCC/C(=N\\OC(=O)c1ccccc1)c1ccc2c(c1)Sc1cc(/C(CCCCCCC)=N/OC(=O)c3ccccc3)ccc1N2c1ccccc1', 'C(CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2c1ccc(C#Cc1ccc(C=NOC(C)=O)cc1)c2)C', 'c14c(cccc1/C(C)=N/OC(C)=O)cccc4/C(C)=N/OC(C)=O', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(/C=N/OC(C)=O)cc2c2cc(/C=N/OC(C)=O)ccc21', 'O=C(O/N=C\\c1ccc2c(c1)Sc1cc(/C=N\\OC(C)=O)ccc1N2CCCC)C', 'CCCCCC(CCCCC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(/C=N/OC(=O)c3ccccc3)cc2c2cc(/C=N/OC(=O)c3ccccc3)ccc21', 'CC(=O)O\\N=C\\c1ccc2c(c1)Sc1cc(/C=N/OC(=O)C)ccc12', 'CCCCCCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(/C=N/OC(=O)c3ccccc3)cc2c2cc(/C=N/OC(=O)c3ccccc3)ccc21', 'CCn1c2ccc(C=NOC(C)=O)cc2c2cc(C=NOC(C)=O)ccc12', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(/C=N/OC(C)=O)cc2c2cc(/C=N/OC(C)=O)ccc21', 'CCCCCCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(/C(C)=N/OC(C)=O)cc2c2cc(/C(C)=N/OC(C)=O)ccc12', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(/C=N/OC(=O)c3ccccc3)cc2c2cc(/C=N/OC(=O)c3ccccc3)ccc21', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCn1c2ccc(/C=N/OC(=O)c3ccccc3)cc2c2cc(/C=N/OC(=O)c3ccccc3)ccc21', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CC(=O)O\\N=C\\c1ccc2c(c1)Sc1cc(/C=N/OC(C)=O)ccc1N2c1ccc(OC)cc1', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'C1C/C(=N/OC(C)=O)c2ccccc2/C1=N\\OC(C)=O', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCCn1c2ccc(/C=N/OC(C)=O)cc2c2cc(/C=N/OC(C)=O)ccc21', 'C=CCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'c1cccc(c12)c(/C(=N/OC(C)=O)C)ccc2/C(C)=N/OC(C)=O', 'CCCCCCn1c2ccc(/C=N/OC(C)=O)cc2c2cc(/C=N/OC(C)=O)ccc21', 'CCCCCCn1c2ccc(/C=N/OC(C)=O)cc2c2cc(/C=N/OC(=O)C)ccc12', 'CC(=O)O\\N=C\\c1ccc2c(c1)Sc1cc(/C=N/OC(C)=O)ccc1N2', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'O=C1c2c(cc(C(=O)/C(C)=N/OC(C)=O)cc2)C(=O)c2ccc(C(=O)/C(=N/OC(C)=O)C)cc21', 'CC(=O)O\\N=C\\c1ccc2cc(/C=N/OC(C)=O)ccc2c1', 'CCCCCCCCCCn1c2ccc(C=NOC(=O)CCl)cc2c2cc(C=NOC(=O)CCl)ccc12', 'CCCCC(CC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCCCCCCCCCn1c2ccc(C=NOC(C)=O)cc2c2cc(C=NOC(C)=O)ccc12', 'CCC(CC)(CC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc12', 'CCCCCN1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2Sc2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CC(=O)O/N=C\\c1ccc2c(c1)Sc1cc(/C=N\\OC(C)=O)ccc1N2C', 'CCCCCCn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCC(CC)Cn1c2ccc(C#Cc3ccc(C=NOC(C)=O)cc3)cc2c2cc(C#Cc3ccc(C=NOC(C)=O)cc3)ccc21', 'CCCCCCn1c2ccc(C=NOC(c3ccc(Cl)cc3)=O)cc2c2cc(C=NOC(=O)c3ccc(Cl)cc3)ccc12', 'CC(=O)O/N=C\\c1ccc2c(c1)Sc1cc(/C=N\\OC(C)=O)ccc1N2c1ccc(Cl)cc1', 'CC(=O)O\\N=C\\c1ccc2ccc(/C=N/OC(C)=O)cc2c1', 'CC(=O)O\\N=C\\c1ccc2c(c1)Sc1cc(/C=N/OC(C)=O)ccc1N2c1ccc(-c2ccccc2)cc1', 'CCCCCCn1c2ccc(-c3ccc(/C=N/OC(C)=O)cc3)cc2c2cc(-c3ccc(/C=N/OC(=O)C)cc3)ccc21', 'O=C(O/N=C/c1ccc2c(c1)Sc1cc(/C=N/OC(=O)c4ccccc4)ccc1N2CCCCC)c2ccccc2',  ...

# %%
def mol2img(mol, img_save_path, text=None):
    # 分子の画像を生成
    img = Draw.MolToImage(mol, size=(300, 300))
    draw = ImageDraw.Draw(img)

    if text is not None:
        font = ImageFont.load_default()
        # テキストの位置を左上に変更
        text_position = (10, 10) # 左上
        draw.text(text_position, text, fill=(0, 0, 0), font=font)

    # 画像をファイルに保存
    img.save(img_save_path)

# %%
for i, smi in enumerate(smiles):
    mol = Chem.MolFromSmiles(smi)
    mol2img(mol, '{}.png'.format(i))
